# %% [markdown]
# # Pre-processing and Training Data Development

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler

# %%
tornado = pd.read_csv('/Users/gregoryolson/Documents/Data Science CT/Capstone/Capstone_Tornado/Data/tornado_downsized.csv')

# %%
tornado.head()
# Out:
#    LATITUDE  LONGITUDE  ELEVATION  DEWP  GUST   MAX   MIN  MXSPD  PRCP  \
# 0  31.61667  -91.28333       82.9  70.2  15.9  90.0  66.9   11.1  0.19
# 1  33.48250  -90.98528       39.0  70.7  18.1  84.0  73.0   13.0  0.01
# 2  33.49630  -90.08660       40.5  74.4  15.0  93.0  75.0    8.9  0.00
# 3  32.32050  -90.07770      100.6  58.0  14.0  91.9  57.0   11.1  0.00
# 4  31.28194  -89.25306       46.0  57.5  19.0  79.0  59.0   12.0  0.00
#
#       SLP   STP  TEMP  VISIB  WDSP  TORNADO  SEASON
# 0  1014.0   4.2  74.7    9.6   5.7        0       2
# 1  1013.7   8.7  76.3    7.4   9.1        0       3
# 2  1015.3  10.7  83.7    9.8   5.1        0       2
# 3  1012.4   0.8  72.6   10.0   2.9        0       4
# 4  1018.5  13.2  66.3    9.9   5.7        0       1

# %%
# create X and y variables
columns = tornado.columns
columns = columns.drop('TORNADO')

X = tornado[columns]
y = tornado['TORNADO']

# %%
# perfom RobustScaler
transformer = RobustScaler().fit(X)
X = transformer.transform(X)
df = pd.DataFrame(X, columns=columns)
df.describe()
# Out:
#          LATITUDE   LONGITUDE   ELEVATION        DEWP        GUST         MAX  \
# count  535.000000  535.000000  535.000000  535.000000  535.000000  535.000000
# mean    -0.065281   -0.205383   -0.067367   -0.178256    0.169505   -0.051353
# std      0.548572    0.641583    0.712313    0.701564    0.952510    0.715640
# min     -0.867325   -1.512418   -1.211462   -2.298734   -0.898876   -2.169591
# 25%     -0.471953   -0.620933   -0.549407   -0.630380   -0.438202   -0.473684
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.528047    0.379067    0.450593    0.369620    0.561798    0.526316
# max      0.882366    0.598227    1.167984    0.875949    4.494382    1.280702
#
#               MIN       MXSPD        PRCP         SLP         STP        TEMP  \
# count  535.000000  535.000000  535.000000  535.000000  535.000000  535.000000
# mean    -0.112624    0.288525    1.273141    0.065047    0.085599   -0.076543
# std      0.626666    0.925443    3.164335    0.817804    0.648207    0.705309
# min     -1.923445   -1.147541   -0.043478   -2.138462   -0.909091   -2.255072
# 25%     -0.569378   -0.327869   -0.043478   -0.430769   -0.443182   -0.504348
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.430622    0.672131    0.956522    0.569231    0.556818    0.495652
# max      0.904306    4.098361   31.217391    2.553846    2.318182    1.118841
#
#             VISIB        WDSP      SEASON
# count  535.000000  535.000000  535.000000
# mean    -0.473917    0.098538    0.110280
# std      1.067634    0.804291    0.540484
# min     -5.818182   -1.282051   -0.500000
# 25%     -0.727273   -0.461538   -0.500000
# 50%      0.000000    0.000000    0.000000
# 75%      0.272727    0.538462    0.500000
# max      0.272727    3.743590    1.000000

# %%
# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=99)
